# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import datetime

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='ac1f41b0f93c45ac8af29623bdf94e0a', client_secret='f2460ff1a77e4c6db5eca633dde46d3b')
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)


# playlist_link = "https://open.spotify.com/playlist/37i9dQZF1DX0XUfTFmNBRM?si=7934cecad3f3439c"
playlist_link = input("Enter the link: ")

playlist_URI = playlist_link.split("/")[-1].split("?")[0]

songs = sp.playlist_tracks(playlist_URI, market='IN')['items']  #will give a list of songs (meta-data)
# print(songs)

# %%
df = pd.DataFrame([])
artists_col = []
for i in range(len(songs)):
    all_artists = songs[i]['track']['artists']
    artists = []
    for a in all_artists:
        artists.append(a['name'])
    artists_col.append(artists)
df['artists'] = artists_col
df
# Out:
#                                             artists
# 0                                 [Imagine Dragons]
# 1                                       [Ryan Mack]
# 2                    [Charlie Puth, Jung Kook, BTS]
# 3                                      [Ed Sheeran]
# 4         [Alan Walker, Sabrina Carpenter, Farruko]
# 5                               [Nicky Youre, dazy]
# 6                    [The Kid LAROI, Justin Bieber]
# 7                                 [Imagine Dragons]
# 8   [salem ilese, TOMORROW X TOGETHER, Alan Walker]
# 9                                   [Justin Bieber]
# 10                       [Ed Sheeran, Armaan Malik]
# 11                                      [Ryan Mack]
# 12                               [Zedd, Elley Duhé]
# 13                                    [OneRepublic]
# 14                               [Jazmine Sullivan]
# 15                                    [salem ilese]
# 16           [Justin Bieber, Daniel Caesar, Giveon]
# 17                                     [Ed Sheeran]
# 18                                     [NIKI DEMAR]
# 19                                   [Shawn Mendes]
# 20                     [Charlie Puth, Selena Gomez]
# 21                                [Imagine Dragons]
# 22                                    [Reagan Beem]
# 23                     [Camila Cabello, Ed Sheeran]
# 24                                      [Ryan Mack]
# 25                                  [Conor Maynard]
# 26                                   [Shawn Mendes]
# 27                                   [Charlie Puth]
# 28                                     [The Weeknd]
# 29                                    [OneRepublic]
# 30                                     [Ed Sheeran]
# 31                                    [AJ Mitchell]
# 32                                  [Conor Maynard]
# 33                   [Shawn Mendes, Camila Cabello]
# 34                                      [Ryan Mack]
# 35    [Lost Frequencies, Elley Duhé, X Ambassadors]
# 36                                          [GAYLE]
# 37                      [Ed Sheeran, Justin Bieber]
# 38             [Imagine Dragons, Miss Congeniality]
# 39                     [Torpe, Baby Tyson, Seb Tik]
# 40                                   [Shawn Mendes]
# 41                                      [Ryan Mack]
# 42                                    [OneRepublic]
# 43                                     [Elley Duhé]
# 44                                       [Confetti]
# 45                                    [salem ilese]
# 46                               [Victoria Justice]
# 47                              [Sabrina Carpenter]
# 48                                      [Ryan Mack]
# 49                                    [OneRepublic]
# 50                                   [Charlie Puth]
# 51                            [Shawn Mendes, Tainy]
# 52                                        [Ruth B.]
# 53                                            [Sia]
# 54                                      [Glee Cast]
# 55                                     [Ed Sheeran]
# 56                      [Alan Walker, Jamie Miller]
# 57                                         [Avicii]
# 58                                  [Glass Animals]
# 59                                   [Armaan Malik]

# %%
df = df.explode('artists').drop_duplicates().reset_index().drop('index', axis=1)
df
# Out:
#                 artists
# 0       Imagine Dragons
# 1             Ryan Mack
# 2          Charlie Puth
# 3             Jung Kook
# 4                   BTS
# 5            Ed Sheeran
# 6           Alan Walker
# 7     Sabrina Carpenter
# 8               Farruko
# 9           Nicky Youre
# 10                 dazy
# 11        The Kid LAROI
# 12        Justin Bieber
# 13          salem ilese
# 14  TOMORROW X TOGETHER
# 15         Armaan Malik
# 16                 Zedd
# 17           Elley Duhé
# 18          OneRepublic
# 19     Jazmine Sullivan
# 20        Daniel Caesar
# 21               Giveon
# 22           NIKI DEMAR
# 23         Shawn Mendes
# 24         Selena Gomez
# 25          Reagan Beem
# 26       Camila Cabello
# 27        Conor Maynard
# 28           The Weeknd
# 29          AJ Mitchell
# 30     Lost Frequencies
# 31        X Ambassadors
# 32                GAYLE
# 33    Miss Congeniality
# 34                Torpe
# 35           Baby Tyson
# 36              Seb Tik
# 37             Confetti
# 38     Victoria Justice
# 39                Tainy
# 40              Ruth B.
# 41                  Sia
# 42            Glee Cast
# 43         Jamie Miller
# 44               Avicii
# 45        Glass Animals

# %%
df1 = pd.read_excel("artists_names.xlsx")
# print(df1.dtypes)
# pd.concat(df, df1)
df1.drop('Unnamed: 0', axis=1, inplace=True)
# print(df1)
df1 = pd.concat([df1, df]).drop_duplicates().reset_index().drop('index', axis=1)

# %%
df1.to_excel('artists_names.xlsx')
df1
# Out:
#                    artists
# 0                   Pritam
# 1             Arijit Singh
# 2     Amitabh Bhattacharya
# 3             Kaifi Khalil
# 4           Tanishk Bagchi
# ...                    ...
# 1225              Confetti
# 1226      Victoria Justice
# 1227                 Tainy
# 1228             Glee Cast
# 1229          Jamie Miller
#
# [1230 rows x 1 columns]
